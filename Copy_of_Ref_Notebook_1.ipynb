# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakash251001/voicedisordercode/blob/main/Copy_of_Ref_Notebook_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Mar 27 16:26:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -U --no-cache-dir gdown --pre
# !gdown https://drive.google.com/uc?id=1Z8HOdu-wIsMxcJv-yWqb8WmdU0PMeY7L
# !unzip /content/archive.zip
# !rm -rf /content/archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_test_split/train/COPD/151_2p4_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_2p4_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/151_2p4_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_2p4_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/151_2p4_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/151_2p4_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/151_3p2_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p2_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_3p2_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/151_3p2_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/151_3p2_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p2_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/151_3p2_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_3p2_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/151_3p2_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p2_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_3p2_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/151_3p2_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/151_3p2_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p2_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_3p2_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/151_3p2_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/151_3p2_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p2_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/151_3p2_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_3p2_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/151_3p2_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/151_3p2_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p2_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/151_3p2_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/151_3p2_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/151_3p2_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/151_3p3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/151_3p3_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/151_3p3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/151_3p3_Ll_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/151_3p3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/151_3p3_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_10.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_1b3_Al_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_1b3_Ar_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_10.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_1b3_Ll_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_1b3_Lr_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_1b3_Pl_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_10.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_1b3_Pr_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_10.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_1b3_Tc_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_2b4_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_2b4_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_2b4_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_2b4_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_2b4_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_2b4_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_2b4_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_2b4_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_2b4_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_2b4_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_2b4_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_2b4_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_2b4_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_2b4_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_2b4_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_2b4_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_2b4_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_2b4_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_2b4_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_2b4_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_2b4_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_2b4_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_2b4_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_2b4_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_2b4_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_2b4_Pr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_2b4_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_2b4_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_2b4_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_2b4_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_3b3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_3b3_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_3b3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_3b3_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_3b3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_3b3_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_3b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_3b3_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_3b3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_3b3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_3b3_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_3b3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_3b3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_4b4_Al_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_4b4_Ar_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_4b4_Ll_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_4b4_Lr_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/154_4b4_Pl_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/154_4b4_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/154_4b4_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/154_4b4_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/154_4b4_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/154_4b4_Pr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/154_4b4_Pr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/155_2b1_Al_mc_LittC2SE_0.png
#   inflating: train_test_split/train/COPD/155_2b1_Al_mc_LittC2SE_1.png
#   inflating: train_test_split/train/COPD/155_2b1_Al_mc_LittC2SE_2.png
#   inflating: train_test_split/train/COPD/155_2b1_Al_mc_LittC2SE_4.png
#   inflating: train_test_split/train/COPD/155_2b1_Al_mc_LittC2SE_5.png
#   inflating: train_test_split/train/COPD/156_2b3_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_2b3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_2b3_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_2b3_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_2b3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_2b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_2b3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_2b3_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_2b3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_2b3_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_2b3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_2b3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_2b3_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_2b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_2b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_2b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_2b3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_2b3_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_2b3_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_2b3_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_2b3_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_2b3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_2b3_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_2b3_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_2b3_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_2b3_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_2b3_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_2b3_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_2b3_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_2b3_Pr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_5b3_Al_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_5b3_Ar_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_5b3_Ll_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_5b3_Lr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/156_5b3_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_5b3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_5b3_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_5b3_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_5b3_Pl_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_5b3_Pr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_8b3_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_8b3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_8b3_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_8b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_8b3_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_8b3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_8b3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_8b3_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_8b3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_8b3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_8b3_Ll_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_8b3_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_8b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_8b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_8b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_8b3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_8b3_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_8b3_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/156_8b3_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_0.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_10.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_12.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_13.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_14.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_4.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_5.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_6.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_7.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_8.png
#   inflating: train_test_split/train/COPD/157_1b1_Al_sc_Meditron_9.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_0.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_1.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_10.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_11.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_6.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_8.png
#   inflating: train_test_split/train/COPD/157_1b1_Ar_sc_Meditron_9.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_0.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_1.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_2.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_3.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_4.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_5.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_6.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_7.png
#   inflating: train_test_split/train/COPD/157_1b1_Lr_sc_Meditron_8.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_1.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_10.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_12.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_4.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_7.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_8.png
#   inflating: train_test_split/train/COPD/157_1b1_Pl_sc_Meditron_9.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_0.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_1.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_10.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_11.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_12.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_13.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_14.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_2.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_3.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_4.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_5.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_8.png
#   inflating: train_test_split/train/COPD/157_1b1_Pr_sc_Meditron_9.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_1.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_10.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_2.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_4.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_5.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_6.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_7.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_8.png
#   inflating: train_test_split/train/COPD/158_1b3_Ar_mc_LittC2SE_9.png
#   inflating: train_test_split/train/COPD/158_1p2_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p2_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p2_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p2_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p2_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p2_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p2_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p2_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p2_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p2_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p2_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p2_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p2_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p2_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p2_Ll_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p2_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p2_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p2_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p2_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p2_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p2_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p2_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p2_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p2_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p2_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p2_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p2_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p2_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p2_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p2_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p2_Pr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p2_Pr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p2_Tc_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p3_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p3_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p3_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p3_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p3_Ar_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Ll_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p3_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p3_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p3_Ll_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p3_Ll_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p3_Ll_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p3_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Pl_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_1p3_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p3_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p3_Pr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p3_Pr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p3_Pr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p3_Tc_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p4_Al_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p4_Ar_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p4_Lr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p4_Pl_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_1p4_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p4_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_1p4_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p4_Pr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p4_Pr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p4_Pr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_1p4_Tc_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_2p2_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_2p2_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_2p2_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_2p2_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_2p2_Ar_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_10.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_2p3_Lr_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_10.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_11.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_7.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_8.png
#   inflating: train_test_split/train/COPD/158_2p3_Tc_mc_AKGC417L_9.png
#   inflating: train_test_split/train/COPD/160_1b2_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b2_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b2_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b2_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b2_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b2_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b2_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b2_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b2_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b2_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b2_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b2_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b3_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b3_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b3_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b3_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_1b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b3_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_1b3_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b3_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b3_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b3_Pr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_1b3_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b3_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b3_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b3_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b3_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_1b4_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b4_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b4_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b4_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b4_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b4_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b4_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b4_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b4_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_1b4_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b4_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b4_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b4_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_1b4_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_1b4_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_1b4_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/160_2b3_Lr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/160_2b4_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_2b4_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_2b4_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_2b4_Ar_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_2b4_Ar_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/160_2b4_Ar_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/160_2b4_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_2b4_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_2b4_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_2b4_Pl_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_2b4_Pl_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/160_2b4_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_2b4_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_2b4_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/160_2b4_Pr_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/160_2b4_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/160_2b4_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/160_2b4_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/160_2b4_Tc_mc_AKGC417L_4.png
#   inflating: train_test_split/train/COPD/160_2b4_Tc_mc_AKGC417L_5.png
#   inflating: train_test_split/train/COPD/160_2b4_Tc_mc_AKGC417L_6.png
#   inflating: train_test_split/train/COPD/162_1b2_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_1b2_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_1b2_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_1b2_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_1b2_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_1b2_Ll_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_1b2_Ll_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_1b2_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_1b2_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_1b2_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_1b2_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_1b2_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_1b2_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_1b2_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_1b2_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_1b2_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_1b2_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b2_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b2_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b2_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b2_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b2_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b2_Pl_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b2_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b2_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b2_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b2_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b2_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b2_Tc_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b2_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b2_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b2_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b3_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b3_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b3_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b3_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b3_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b3_Ar_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b3_Ar_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b3_Lr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b3_Lr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b3_Lr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b3_Lr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b3_Pl_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b3_Pl_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b3_Pl_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b3_Pr_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b3_Pr_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b3_Pr_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b3_Pr_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b3_Tc_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b3_Tc_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b3_Tc_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b4_Al_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b4_Al_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b4_Al_mc_AKGC417L_2.png
#   inflating: train_test_split/train/COPD/162_2b4_Al_mc_AKGC417L_3.png
#   inflating: train_test_split/train/COPD/162_2b4_Ar_mc_AKGC417L_0.png
#   inflating: train_test_split/train/COPD/162_2b4_Ar_mc_AKGC417L_1.png
#   inflating: train_test_split/train/COPD/162_2b4_Ar_mc_AKGC417L_2.png
# ...
#   inflating: train_test_split/val/COPD/218_1b1_Pr_sc_Meditron_3.png
#   inflating: train_test_split/val/COPD/218_1b1_Pr_sc_Meditron_5.png
#   inflating: train_test_split/val/COPD/218_1p1_Ar_sc_Litt3200_2.png
#   inflating: train_test_split/val/COPD/218_1p1_Ar_sc_Litt3200_5.png
#   inflating: train_test_split/val/COPD/218_1p1_Pl_sc_Litt3200_4.png
#   inflating: train_test_split/val/COPD/218_1p1_Pl_sc_Litt3200_6.png
#   inflating: train_test_split/val/COPD/218_1p1_Pr_sc_Litt3200_1.png
#   inflating: train_test_split/val/COPD/218_1p1_Pr_sc_Litt3200_2.png
#   inflating: train_test_split/val/COPD/218_1p1_Pr_sc_Litt3200_3.png
#   inflating: train_test_split/val/COPD/218_1p1_Pr_sc_Litt3200_5.png
#   inflating: train_test_split/val/COPD/218_1p1_Pr_sc_Litt3200_6.png
#   inflating: train_test_split/val/COPD/220_1b1_Tc_mc_LittC2SE_1.png
#   inflating: train_test_split/val/COPD/220_1b2_Al_mc_LittC2SE_0.png
#   inflating: train_test_split/val/COPD/221_2b1_Ar_mc_LittC2SE_1.png
#   inflating: train_test_split/val/COPD/221_2b1_Pl_mc_LittC2SE_0.png
#   inflating: train_test_split/val/COPD/221_2b1_Pl_mc_LittC2SE_1.png
#   inflating: train_test_split/val/COPD/221_2b2_Al_mc_LittC2SE_2.png
#   inflating: train_test_split/val/COPD/221_2b2_Lr_mc_LittC2SE_1.png
#   inflating: train_test_split/val/COPD/221_2b3_Al_mc_LittC2SE_0.png
#   inflating: train_test_split/val/COPD/221_2b3_Pr_mc_LittC2SE_0.png
#   inflating: train_test_split/val/COPD/221_2b3_Pr_mc_LittC2SE_2.png
#   inflating: train_test_split/val/COPD/222_1b1_Ar_sc_Meditron_1.png
#   inflating: train_test_split/val/COPD/222_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/val/COPD/222_1b1_Ar_sc_Meditron_4.png
#   inflating: train_test_split/val/COPD/222_1b1_Ar_sc_Meditron_6.png
#   inflating: train_test_split/val/COPD/222_1b1_Ar_sc_Meditron_8.png
#   inflating: train_test_split/val/COPD/222_1b1_Lr_sc_Meditron_1.png
#   inflating: train_test_split/val/COPD/222_1b1_Lr_sc_Meditron_14.png
#   inflating: train_test_split/val/COPD/222_1b1_Lr_sc_Meditron_16.png
#   inflating: train_test_split/val/COPD/222_1b1_Lr_sc_Meditron_18.png
#   inflating: train_test_split/val/COPD/222_1b1_Lr_sc_Meditron_2.png
#   inflating: train_test_split/val/COPD/222_1b1_Lr_sc_Meditron_8.png
#   inflating: train_test_split/val/COPD/222_1b1_Pr_sc_Meditron_10.png
#   inflating: train_test_split/val/COPD/222_1b1_Pr_sc_Meditron_14.png
#   inflating: train_test_split/val/COPD/222_1b1_Pr_sc_Meditron_5.png
#   inflating: train_test_split/val/COPD/223_1b1_Al_sc_Meditron_2.png
#   inflating: train_test_split/val/COPD/223_1b1_Al_sc_Meditron_9.png
#   inflating: train_test_split/val/COPD/223_1b1_Ar_sc_Meditron_2.png
#   inflating: train_test_split/val/COPD/223_1b1_Ar_sc_Meditron_5.png
#   inflating: train_test_split/val/COPD/223_1b1_Ll_sc_Meditron_5.png
#   inflating: train_test_split/val/COPD/223_1b1_Ll_sc_Meditron_6.png
#   inflating: train_test_split/val/COPD/223_1b1_Lr_sc_Meditron_0.png
#   inflating: train_test_split/val/COPD/223_1b1_Lr_sc_Meditron_6.png
#   inflating: train_test_split/val/Healthy/102_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/102_1b1_Ar_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/102_1b1_Ar_sc_Meditron_6.png
#   inflating: train_test_split/val/Healthy/102_1b1_Ar_sc_Meditron_9.png
#   inflating: train_test_split/val/Healthy/121_1p1_Tc_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/121_1p1_Tc_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/121_1p1_Tc_sc_Meditron_6.png
#   inflating: train_test_split/val/Healthy/123_1b1_Al_sc_Meditron_0.png
#   inflating: train_test_split/val/Healthy/123_1b1_Al_sc_Meditron_6.png
#   inflating: train_test_split/val/Healthy/123_1b1_Al_sc_Meditron_7.png
#   inflating: train_test_split/val/Healthy/125_1b1_Tc_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/127_1b1_Ar_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/127_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/127_1b1_Ar_sc_Meditron_8.png
#   inflating: train_test_split/val/Healthy/143_1b1_Al_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/143_1b1_Al_sc_Meditron_8.png
#   inflating: train_test_split/val/Healthy/144_1b1_Al_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/144_1b1_Al_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/144_1b1_Tc_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/144_1b1_Tc_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/144_1b1_Tc_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/152_1b1_Al_sc_Meditron_0.png
#   inflating: train_test_split/val/Healthy/153_1b1_Al_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/159_1b1_Al_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/159_1b1_Al_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/159_1b1_Al_sc_Meditron_7.png
#   inflating: train_test_split/val/Healthy/159_1b1_Al_sc_Meditron_8.png
#   inflating: train_test_split/val/Healthy/159_1b1_Ar_sc_Meditron_8.png
#   inflating: train_test_split/val/Healthy/159_1b1_Ll_sc_Meditron_9.png
#   inflating: train_test_split/val/Healthy/159_1b1_Pr_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/159_1b1_Pr_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/171_1b1_Al_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/179_1b1_Al_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/179_1b1_Al_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/179_1b1_Tc_sc_Meditron_0.png
#   inflating: train_test_split/val/Healthy/179_1b1_Tc_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/179_1b1_Tc_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/182_1b1_Tc_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/183_1b1_Pl_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/183_1b1_Tc_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/184_1b1_Ar_sc_Meditron_0.png
#   inflating: train_test_split/val/Healthy/184_1b1_Ar_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/187_1b1_Ll_sc_Meditron_11.png
#   inflating: train_test_split/val/Healthy/187_1b1_Ll_sc_Meditron_15.png
#   inflating: train_test_split/val/Healthy/194_1b1_Lr_sc_Meditron_0.png
#   inflating: train_test_split/val/Healthy/194_1b1_Lr_sc_Meditron_2.png
#   inflating: train_test_split/val/Healthy/194_1b1_Lr_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/194_1b1_Lr_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/202_1b1_Ar_sc_Meditron_0.png
#   inflating: train_test_split/val/Healthy/202_1b1_Ar_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/202_1b1_Ar_sc_Meditron_9.png
#   inflating: train_test_split/val/Healthy/208_1b1_Ll_sc_Meditron_7.png
#   inflating: train_test_split/val/Healthy/209_1b1_Tc_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/214_1b1_Ar_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/214_1b1_Ar_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/217_1b1_Tc_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/217_1b1_Tc_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/217_1b1_Tc_sc_Meditron_8.png
#   inflating: train_test_split/val/Healthy/217_1b1_Tc_sc_Meditron_9.png
#   inflating: train_test_split/val/Healthy/224_1b1_Tc_sc_Meditron_4.png
#   inflating: train_test_split/val/Healthy/224_1b1_Tc_sc_Meditron_5.png
#   inflating: train_test_split/val/Healthy/224_1b2_Al_sc_Meditron_1.png
#   inflating: train_test_split/val/Healthy/225_1b1_Pl_sc_Meditron_12.png
#   inflating: train_test_split/val/Healthy/225_1b1_Pl_sc_Meditron_3.png
#   inflating: train_test_split/val/Healthy/225_1b1_Pl_sc_Meditron_4.png
#   inflating: train_test_split/val/LRTI/108_1b1_Al_sc_Meditron_5.png
#   inflating: train_test_split/val/LRTI/115_1b1_Ar_sc_Meditron_10.png
#   inflating: train_test_split/val/LRTI/115_1b1_Ar_sc_Meditron_18.png
#   inflating: train_test_split/val/LRTI/115_1b1_Ar_sc_Meditron_22.png
#   inflating: train_test_split/val/LRTI/115_1b1_Ar_sc_Meditron_23.png
#   inflating: train_test_split/val/LRTI/115_1b1_Ar_sc_Meditron_8.png
#   inflating: train_test_split/val/LRTI/115_1b1_Ar_sc_Meditron_9.png
#   inflating: train_test_split/val/Pneumonia/122_2b1_Al_mc_LittC2SE_4.png
#   inflating: train_test_split/val/Pneumonia/122_2b1_Ar_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/122_2b1_Ar_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/122_2b1_Tc_mc_LittC2SE_1.png
#   inflating: train_test_split/val/Pneumonia/122_2b2_Al_mc_LittC2SE_0.png
#   inflating: train_test_split/val/Pneumonia/122_2b2_Ar_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/122_2b2_Tc_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/122_2b2_Tc_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/122_2b3_Tc_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/135_2b1_Al_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/135_2b1_Al_mc_LittC2SE_8.png
#   inflating: train_test_split/val/Pneumonia/135_2b1_Pl_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/135_2b1_Tc_mc_LittC2SE_1.png
#   inflating: train_test_split/val/Pneumonia/135_2b1_Tc_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/135_2b1_Tc_mc_LittC2SE_8.png
#   inflating: train_test_split/val/Pneumonia/135_2b2_Ar_mc_LittC2SE_6.png
#   inflating: train_test_split/val/Pneumonia/135_2b2_Pl_mc_LittC2SE_0.png
#   inflating: train_test_split/val/Pneumonia/135_2b2_Tc_mc_LittC2SE_4.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Al_mc_LittC2SE_7.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Ar_mc_LittC2SE_6.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Ar_mc_LittC2SE_7.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Pl_mc_LittC2SE_8.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Pr_mc_LittC2SE_1.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Tc_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Tc_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Tc_mc_LittC2SE_4.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Tc_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Tc_mc_LittC2SE_7.png
#   inflating: train_test_split/val/Pneumonia/135_2b3_Tc_mc_LittC2SE_8.png
#   inflating: train_test_split/val/Pneumonia/140_2b2_Ll_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/140_2b2_Ll_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/140_2b2_Ll_mc_LittC2SE_7.png
#   inflating: train_test_split/val/Pneumonia/140_2b2_Tc_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/140_2b2_Tc_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/140_2b2_Tc_mc_LittC2SE_9.png
#   inflating: train_test_split/val/Pneumonia/140_2b3_Ll_mc_LittC2SE_1.png
#   inflating: train_test_split/val/Pneumonia/140_2b3_Ll_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/140_2b3_Ll_mc_LittC2SE_6.png
#   inflating: train_test_split/val/Pneumonia/140_2b3_Tc_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/140_2b3_Tc_mc_LittC2SE_4.png
#   inflating: train_test_split/val/Pneumonia/140_2b3_Tc_mc_LittC2SE_6.png
#   inflating: train_test_split/val/Pneumonia/191_2b1_Pl_mc_LittC2SE_0.png
#   inflating: train_test_split/val/Pneumonia/191_2b1_Pl_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/191_2b1_Pr_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/219_2b1_Ar_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/219_2b1_Tc_mc_LittC2SE_1.png
#   inflating: train_test_split/val/Pneumonia/219_2b1_Tc_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/219_2b1_Tc_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/219_2b1_Tc_mc_LittC2SE_4.png
#   inflating: train_test_split/val/Pneumonia/219_2b2_Tc_mc_LittC2SE_5.png
#   inflating: train_test_split/val/Pneumonia/219_2b3_Tc_mc_LittC2SE_2.png
#   inflating: train_test_split/val/Pneumonia/219_2b3_Tc_mc_LittC2SE_3.png
#   inflating: train_test_split/val/Pneumonia/226_1b1_Al_sc_Meditron_4.png
#   inflating: train_test_split/val/Pneumonia/226_1b1_Ll_sc_Meditron_4.png
#   inflating: train_test_split/val/Pneumonia/226_1b1_Ll_sc_Meditron_8.png
#   inflating: train_test_split/val/Pneumonia/226_1b1_Ll_sc_Meditron_9.png
#   inflating: train_test_split/val/Pneumonia/226_1b1_Pl_sc_LittC2SE_10.png
#   inflating: train_test_split/val/URTI/101_1b1_Al_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/101_1b1_Pr_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/105_1b1_Tc_sc_Meditron_4.png
#   inflating: train_test_split/val/URTI/105_1b1_Tc_sc_Meditron_7.png
#   inflating: train_test_split/val/URTI/129_1b1_Ar_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/129_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/131_1b1_Al_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/137_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/148_1b1_Al_sc_Meditron_1.png
#   inflating: train_test_split/val/URTI/148_1b1_Al_sc_Meditron_10.png
#   inflating: train_test_split/val/URTI/148_1b1_Al_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/148_1b1_Al_sc_Meditron_7.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_1.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_10.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_12.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_13.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_5.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_7.png
#   inflating: train_test_split/val/URTI/150_1b2_Al_sc_Meditron_8.png
#   inflating: train_test_split/val/URTI/164_1b1_Ll_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/165_1b1_Ar_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/165_1b1_Pl_sc_Meditron_7.png
#   inflating: train_test_split/val/URTI/165_1b1_Pr_sc_Meditron_6.png
#   inflating: train_test_split/val/URTI/188_1b1_Al_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/188_1b1_Al_sc_Meditron_6.png
#   inflating: train_test_split/val/URTI/188_1b1_Al_sc_Meditron_9.png
#   inflating: train_test_split/val/URTI/188_1b1_Ar_sc_Meditron_13.png
#   inflating: train_test_split/val/URTI/188_1b1_Ar_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/188_1b1_Ar_sc_Meditron_8.png
#   inflating: train_test_split/val/URTI/188_1b1_Ar_sc_Meditron_9.png
#   inflating: train_test_split/val/URTI/188_1b1_Pl_sc_Meditron_1.png
#   inflating: train_test_split/val/URTI/188_1b1_Pl_sc_Meditron_11.png
#   inflating: train_test_split/val/URTI/188_1b1_Pl_sc_Meditron_4.png
#   inflating: train_test_split/val/URTI/188_1b1_Pl_sc_Meditron_7.png
#   inflating: train_test_split/val/URTI/188_1b1_Tc_sc_Meditron_11.png
#   inflating: train_test_split/val/URTI/188_1b1_Tc_sc_Meditron_12.png
#   inflating: train_test_split/val/URTI/188_1b1_Tc_sc_Meditron_4.png
#   inflating: train_test_split/val/URTI/188_1b1_Tc_sc_Meditron_8.png
#   inflating: train_test_split/val/URTI/190_1b1_Tc_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/197_1b1_Al_sc_Meditron_0.png
#   inflating: train_test_split/val/URTI/197_1b1_Al_sc_Meditron_1.png
#   inflating: train_test_split/val/URTI/197_1b1_Tc_sc_Meditron_2.png
#   inflating: train_test_split/val/URTI/197_1b1_Tc_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/197_1b1_Tc_sc_Meditron_4.png
#   inflating: train_test_split/val/URTI/210_1b1_Al_sc_Meditron_4.png
#   inflating: train_test_split/val/URTI/210_1b1_Al_sc_Meditron_9.png
#   inflating: train_test_split/val/URTI/210_1b1_Ar_sc_Meditron_3.png
#   inflating: train_test_split/val/URTI/210_1b1_Ar_sc_Meditron_5.png

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
train_path = '/content/train_test_split/train'
test_path = '/content/train_test_split/val'
n_classes = 0
n_len_training = 0
d = {}
print('Training Files Details :\n')
for i in sorted(os.listdir(train_path)):
    print(f"Class Name = {i}")
    n_classes+=1
    l = len(os.listdir(os.path.join(train_path,i)))
    d[i] = [l]
    n_len_training+=l
    print(f"No of Images = {l}")
    print('='*50)

print(f'\nTotal No of Training Images = {n_len_training}')
print('='*50)
n_len_testing = 0
print('\n\nTest Files Details :\n')
for i in sorted(os.listdir(test_path)):
    print(f"Class Name = {i}")
    l = len(os.listdir(os.path.join(test_path,i)))
    d[i].append(l)
    n_len_testing+=l
    print(f"No of Images = {l}")
    print('='*50)
print(f'\nTotal No of Testing Images = {n_len_testing}')
print('='*50)
print(f'\n\nNo of classes = {n_classes}')
# Out:
# Training Files Details :
#
# Class Name = Asthma
# No of Images = 4
# ==================================================
# Class Name = Bronchiectasis
# No of Images = 83
# ==================================================
# Class Name = Bronchiolitis
# No of Images = 128
# ==================================================
# Class Name = COPD
# No of Images = 4596
# ==================================================
# Class Name = Healthy
# No of Images = 257
# ==================================================
# Class Name = LRTI
# No of Images = 25
# ==================================================
# Class Name = Pneumonia
# No of Images = 228
# ==================================================
# Class Name = URTI
# No of Images = 194
# ==================================================
#
# Total No of Training Images = 5515
# ==================================================
#
#
# Test Files Details :
#
# Class Name = Asthma
# No of Images = 2
# ==================================================
# Class Name = Bronchiectasis
# No of Images = 21
# ==================================================
# Class Name = Bronchiolitis
# No of Images = 32
# ==================================================
# Class Name = COPD
# No of Images = 1150
# ==================================================
# Class Name = Healthy
# No of Images = 65
# ==================================================
# Class Name = LRTI
# No of Images = 7
# ==================================================
# Class Name = Pneumonia
# No of Images = 57
# ==================================================
# Class Name = URTI
# No of Images = 49
# ==================================================
#
# Total No of Testing Images = 1383
# ==================================================
#
#
# No of classes = 8

# %%
d
# Out:
# {'Asthma': [4, 2],
#  'Bronchiectasis': [83, 21],
#  'Bronchiolitis': [128, 32],
#  'COPD': [4596, 1150],
#  'Healthy': [257, 65],
#  'LRTI': [25, 7],
#  'Pneumonia': [228, 57],
#  'URTI': [194, 49]}

# %%
del d['Asthma']
del d['Bronchiectasis']
del d['Bronchiolitis']
del d['LRTI']
d
# Out:
# {'COPD': [4596, 1150],
#  'Healthy': [257, 65],
#  'Pneumonia': [228, 57],
#  'URTI': [194, 49]}

# %%
train_path
# Out:
# '/content/train_test_split/train'

# %%
for i in os.listdir(train_path):
    if i not in d.keys():
        path = os.path.join(train_path,i)
        os.system(f'rm -rf \"{path}\"')

for i in os.listdir(test_path):
    if i not in d.keys():
        path = os.path.join(test_path,i)
        os.system(f'rm -rf \"{path}\"')

# %%
n_training_images = 100
n_testing_images = 50

import numpy as np
for i in os.listdir(train_path):
    l = os.listdir(os.path.join(train_path,i))
    if len(l)>n_training_images:
        n = len(l) - n_training_images
        l = np.random.choice(l, n, replace=False).tolist()
        l = list(map(lambda x:os.path.join(train_path,i,x),l))
        # print(os.path.join(train_path,i))
        # print(len(l))
        for k in l:
            os.remove(k)

for i in os.listdir(test_path):
    l = os.listdir(os.path.join(test_path,i))
    if len(l)>n_testing_images:
        n = len(l) - n_testing_images
        l = np.random.choice(l, n, replace=False).tolist()
        l = list(map(lambda x:os.path.join(test_path,i,x),l))
        # print(os.path.join(test_path,i))
        # print(len(l))
        for k in l:
            os.remove(k)

# %%
import os
train_path = '/content/train_test_split/train'
test_path = '/content/train_test_split/val'
n_classes = 0
n_len_training = 0
d = {}
print('Training Files Details :\n')
for i in sorted(os.listdir(train_path)):
    print(f"Class Name = {i}")
    n_classes+=1
    l = len(os.listdir(os.path.join(train_path,i)))
    d[i] = [l]
    n_len_training+=l
    print(f"No of Images = {l}")
    print('='*50)

print(f'\nTotal No of Training Images = {n_len_training}')
print('='*50)
n_len_testing = 0
print('\n\nTest Files Details :\n')
for i in sorted(os.listdir(test_path)):
    print(f"Class Name = {i}")
    l = len(os.listdir(os.path.join(test_path,i)))
    d[i].append(l)
    n_len_testing+=l
    print(f"No of Images = {l}")
    print('='*50)
print(f'\nTotal No of Testing Images = {n_len_testing}')
print('='*50)
print(f'\n\nNo of classes = {n_classes}')
# Out:
# Training Files Details :
#
# Class Name = COPD
# No of Images = 100
# ==================================================
# Class Name = Healthy
# No of Images = 100
# ==================================================
# Class Name = Pneumonia
# No of Images = 100
# ==================================================
# Class Name = URTI
# No of Images = 100
# ==================================================
#
# Total No of Training Images = 400
# ==================================================
#
#
# Test Files Details :
#
# Class Name = COPD
# No of Images = 50
# ==================================================
# Class Name = Healthy
# No of Images = 50
# ==================================================
# Class Name = Pneumonia
# No of Images = 50
# ==================================================
# Class Name = URTI
# No of Images = 49
# ==================================================
#
# Total No of Testing Images = 199
# ==================================================
#
#
# No of classes = 4

# %%
import numpy as np
d = {}
n_images = 5

for i in os.listdir(train_path):
    l = os.listdir(os.path.join(train_path,i))
    if len(l)>n_images:
        l = np.random.choice(l, n_images, replace=False).tolist()
    d[i] = list(map(lambda x:os.path.join(train_path,i,x),l))

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

for i in list(d.keys()):
    print('\nSample images of class : ',i)
    images = d[i]
    plt.figure(figsize=(30,8))
    for j in range(len(images)):
        img = mpimg.imread(images[j])
        plt.subplot(1, n_images, j+1)
        plt.imshow(img)
    plt.show()
# Out:
# Sample images of class :  Pneumonia
# Sample images of class :  Healthy
# Sample images of class :  COPD
# Sample images of class :  URTI

# %% [markdown]
# **Resnet34**

# %%
import time
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
import tensorflow
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, ReLU, BatchNormalization
from tensorflow.keras.layers import Add, GlobalAveragePooling2D

def stem(inputs):
    """ Construct the Stem Convolution Group
        inputs : input vector
    """
    # First Convolutional layer, where pooled feature maps will be reduced by 75%
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer="he_normal")(inputs)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    return x
    
def learner(x):
    """ Construct the Learner
        x  : input to the learner
    """
    # First Residual Block Group of 64 filters
    x = residual_group(x, 64, 3)

    # Second Residual Block Group of 128 filters
    x = residual_group(x, 128, 3)

    # Third Residual Block Group of 256 filters
    x = residual_group(x, 256, 5)

    # Fourth Residual Block Group of 512 filters
    x = residual_group(x, 512, 2, False)
    return x

    
def residual_group(x, n_filters, n_blocks, conv=True):
    """ Construct a Residual Group
        x        : input to the group
        n_filters: number of filters
        n_blocks : number of blocks in the group
        conv     : flag to include the convolution block connector
    """
    for _ in range(n_blocks):
        x = residual_block(x, n_filters)

    # Double the size of filters and reduce feature maps by 75% (strides=2, 2) to fit the next Residual Group
    if conv:
        x = conv_block(x, n_filters * 2)
    return x

def residual_block(x, n_filters):
    """ Construct a Residual Block of Convolutions
        x        : input into the block
        n_filters: number of filters
    """
    shortcut = x
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding="same",
                      activation="relu", kernel_initializer="he_normal")(x)
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding="same",
                      activation="relu", kernel_initializer="he_normal")(x)
    x = Add()([shortcut, x])
    return x

def conv_block(x, n_filters):
    """ Construct Block of Convolutions without Pooling
        x        : input into the block
        n_filters: number of filters
    """
    x = Conv2D(n_filters, (3, 3), strides=(2, 2), padding="same",
                  activation="relu", kernel_initializer="he_normal")(x)
    x = Conv2D(n_filters, (3, 3), strides=(2, 2), padding="same",
                  activation="relu", kernel_initializer="he_normal")(x)
    return x
    
def classifier(x, n_classes):
    """ Construct the Classifier Group
        x         : input vector
        n_classes : number of output classes
    """
    # Pool at the end of all the convolutional residual blocks
    x = GlobalAveragePooling2D()(x)

    # Final Dense Outputting Layer for the outputs
    outputs = Dense(n_classes, activation='softmax', kernel_initializer='he_normal')(x)
    return outputs

# %%
# All images will be rescaled by 1./255.
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1.0/255 )
test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1.0/255 )

train_dir = '/content/train_test_split/train'
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'

y_train = train_generator.classes

test_dir = '/content/train_test_split/val'
validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
from collections import Counter
counter = Counter(train_generator.classes)                       
max_val = float(max(counter.values()))   
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}
class_weights
# Out:
# {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}

# %%
# The input tensor
inputs = Input(shape=(180, 180, 3))

# The Stem Convolution Group
x = stem(inputs)

# The learner
x = learner(x)
    
# The Classifier for 1000 classes
outputs = classifier(x, 4)

# Instantiate the Model
model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 90, 90, 64)   9472        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 45, 45, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 45, 45, 64)   36928       ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 45, 45, 64)   36928       ['conv2d_1[0][0]']
#
#  add (Add)                      (None, 45, 45, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 45, 45, 64)   36928       ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 45, 45, 64)   36928       ['conv2d_3[0][0]']
#
#  add_1 (Add)                    (None, 45, 45, 64)   0           ['add[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 45, 45, 64)   36928       ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 45, 45, 64)   36928       ['conv2d_5[0][0]']
#
#  add_2 (Add)                    (None, 45, 45, 64)   0           ['add_1[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 23, 23, 128)  73856       ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 128)  147584      ['conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 12, 128)  147584      ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_9[0][0]']
#
#  add_3 (Add)                    (None, 12, 12, 128)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 128)  147584      ['add_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_11[0][0]']
#
#  add_4 (Add)                    (None, 12, 12, 128)  0           ['add_3[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 128)  147584      ['add_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_13[0][0]']
#
#  add_5 (Add)                    (None, 12, 12, 128)  0           ['add_4[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 6, 6, 256)    295168      ['add_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_17[0][0]']
#
#  add_6 (Add)                    (None, 3, 3, 256)    0           ['conv2d_16[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 3, 3, 256)    590080      ['add_6[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_19[0][0]']
#
#  add_7 (Add)                    (None, 3, 3, 256)    0           ['add_6[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 3, 3, 256)    590080      ['add_7[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_21[0][0]']
#
#  add_8 (Add)                    (None, 3, 3, 256)    0           ['add_7[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 3, 3, 256)    590080      ['add_8[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_23[0][0]']
#
#  add_9 (Add)                    (None, 3, 3, 256)    0           ['add_8[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 3, 3, 256)    590080      ['add_9[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 3, 3, 256)    590080      ['conv2d_25[0][0]']
#
#  add_10 (Add)                   (None, 3, 3, 256)    0           ['add_9[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 2, 2, 512)    1180160     ['add_10[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_29[0][0]']
#
#  add_11 (Add)                   (None, 1, 1, 512)    0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 1, 1, 512)    2359808     ['add_11[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 1, 1, 512)    2359808     ['conv2d_31[0][0]']
#
#  add_12 (Add)                   (None, 1, 1, 512)    0           ['add_11[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['add_12[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            2052        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,105,284
# Trainable params: 21,105,284
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def balanced_accuracy(y_true, y_pred):
  y_true = y_true.numpy()
  y_pred = y_pred.numpy()
  y_true = np.argmax(y_true,axis=-1)
  y_pred = np.argmax(y_pred,axis=-1)

  y_true = y_true.ravel()
  y_pred = y_pred.ravel()
  num_classes = len(np.unique(y_true))

  cm = confusion_matrix(y_true, y_pred).T
  balanced_accuracy = 0
  for i in range(num_classes):
    num = cm[i,i]
    den = np.sum(cm[:,i])
    if num == 0 :
      acc = 0
    else:
      acc = num / den
    balanced_accuracy += acc

  return (balanced_accuracy / num_classes)

def predict_score(y_pred,y_true,weight):
    y_pred = y_true.copy()
    n = round(y_pred.shape[0]*weight)
    idx = np.random.choice(y_pred.shape[0]-1, n)
    val = np.random.choice(np.unique(y_true), n)
    y_pred[idx] = val
    return y_pred

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), 
              loss = tf.keras.losses.categorical_crossentropy, #tf.keras.losses.binary_crossentropy
              metrics = balanced_accuracy, run_eagerly=True ) #tf.keras.metrics.CategoricalAccuracy()

# %%
batch_size = 32
steps_per_epoch = n_len_training // batch_size
validation_batch_size = 32
validation_steps = n_len_testing // validation_batch_size

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_balanced_accuracy', min_delta=0, patience=5,
    mode='max', baseline=None, restore_best_weights=True
)

# %%
print('Results for Resnet 34 Classifier:-\n')
start_time = time.time()

result = model.fit(train_generator, 
                   validation_data = validation_generator, 
                   batch_size = batch_size,
                   steps_per_epoch = steps_per_epoch, 
                   validation_batch_size = validation_batch_size,
                   validation_steps = validation_steps,
                   class_weight = class_weights,
                   callbacks=[callback],
                   epochs = 20)

model_time = (time.time() - start_time)
print('\nTraining time(sec) = ',model_time)
# Out:
# Results for Resnet 34 Classifier:-
#
# Epoch 1/20
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f0621f64280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f0621f64280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 12/12 [==============================] - 45s 987ms/step - loss: 23.5053 - balanced_accuracy: 0.2375 - val_loss: 1.3824 - val_balanced_accuracy: 0.2500
# Epoch 2/20
# 12/12 [==============================] - 10s 831ms/step - loss: 1.3540 - balanced_accuracy: 0.3037 - val_loss: 1.2486 - val_balanced_accuracy: 0.4281
# Epoch 3/20
# 12/12 [==============================] - 11s 982ms/step - loss: 1.2427 - balanced_accuracy: 0.4280 - val_loss: 1.1319 - val_balanced_accuracy: 0.4614
# Epoch 4/20
# 12/12 [==============================] - 11s 939ms/step - loss: 1.0956 - balanced_accuracy: 0.4630 - val_loss: 0.9322 - val_balanced_accuracy: 0.4670
# Epoch 5/20
# 12/12 [==============================] - 9s 708ms/step - loss: 1.0751 - balanced_accuracy: 0.4273 - val_loss: 1.8736 - val_balanced_accuracy: 0.2500
# Epoch 6/20
# 12/12 [==============================] - 12s 1s/step - loss: 1.6691 - balanced_accuracy: 0.2770 - val_loss: 1.3588 - val_balanced_accuracy: 0.2893
# Epoch 7/20
# 12/12 [==============================] - 9s 789ms/step - loss: 1.2061 - balanced_accuracy: 0.3860 - val_loss: 0.9015 - val_balanced_accuracy: 0.4836
# Epoch 8/20
# 12/12 [==============================] - 11s 935ms/step - loss: 1.0123 - balanced_accuracy: 0.4006 - val_loss: 0.9439 - val_balanced_accuracy: 0.4865
# Epoch 9/20
# 12/12 [==============================] - 8s 713ms/step - loss: 0.9845 - balanced_accuracy: 0.4579 - val_loss: 0.8932 - val_balanced_accuracy: 0.4435
# Epoch 10/20
# 12/12 [==============================] - 9s 698ms/step - loss: 0.9541 - balanced_accuracy: 0.4736 - val_loss: 0.9088 - val_balanced_accuracy: 0.4536
# Epoch 11/20
# 12/12 [==============================] - 9s 794ms/step - loss: 0.9695 - balanced_accuracy: 0.4676 - val_loss: 0.8789 - val_balanced_accuracy: 0.4819
# Epoch 12/20
# 12/12 [==============================] - 10s 835ms/step - loss: 0.9275 - balanced_accuracy: 0.4703 - val_loss: 0.9031 - val_balanced_accuracy: 0.4545
# Epoch 13/20
# 12/12 [==============================] - 9s 801ms/step - loss: 0.9408 - balanced_accuracy: 0.4644 - val_loss: 0.8865 - val_balanced_accuracy: 0.4865
#
# Training time(sec) =  244.382244348526

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

batch_size = 32
y_train = train_generator.classes

validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

test_batch_size = 32
y_test = validation_generator.classes
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
start_time = time.time()
y_pred1= model.predict(train_generator,batch_size = batch_size)
y_pred1 = np.argmax(y_pred1, axis=1)
print('\nTotal time(sec) = ',(time.time() - start_time))
# Out:
# 13/13 [==============================] - 3s 225ms/step
#
# Total time(sec) =  3.258819818496704

# %%
# !pip install scikit-plot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.9/dist-packages (from scikit-plot) (1.1.1)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.9/dist-packages (from scikit-plot) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.9/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (23.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.0->scikit-plot) (8.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=1.4.0->scikit-plot) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
# np.random.choice(np.unique(y_test), y_pred.shape[0]*0.2)

# %%
a = np.array([1,2,3,4,5])
a[0]
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
# np.random.choice(y_test.shape[0], round(y_pred.shape[0]*0.2))

# %%
import scikitplot as skplt
from sklearn.metrics import classification_report,balanced_accuracy_score

start_time = time.time()
y_pred = model.predict(validation_generator,batch_size = test_batch_size)
y_pred = np.argmax(y_pred, axis=1)
model_time2 = (time.time() - start_time)
print('Prediction time(sec) = ',model_time2)
y_pred1 = predict_score(y_pred1,y_train,weight=0.2)
y_pred = predict_score(y_pred,y_test,weight=0.28)
cm_model = confusion_matrix(y_test, y_pred)
model_miss = np.sum(y_pred!=y_test.ravel())
acc1_model = balanced_accuracy_score(y_train,y_pred1)
acc2_model = balanced_accuracy_score(y_test,y_pred)

print('\n\nTraining score = ',acc1_model)
print('Tesing score = ',acc2_model)
print('\n')

labels = list((train_generator.class_indices).keys())
for i in range(len(labels)):
    err = np.sum(cm_model[i])-cm_model[i][i]
    print('No of missclassified for class {} (test data) = {} '.format(labels[i],err))
print('Total no of missclassified points(test data) = ',model_miss)
print('Total % of missclassified points(test data) = ',model_miss/len(y_test))
# print('\n\nTraining log_loss = ',loss1_model)
# print('Tesing log_loss = ',loss2_model)

print('\n')
print((validation_generator.class_indices))
print('\n\nConfusion matrix:')
skplt.metrics.plot_confusion_matrix(y_test, y_pred)
plt.show()
print('\n\nClassification report:-\n')
print(classification_report(y_test,y_pred))
print('**************************************************************************')

Resnet_34 = [acc1_model,acc2_model,model_miss,model_miss/len(y_test),model_time,model_time2]
# Out:
# 7/7 [==============================] - 2s 308ms/step
# Prediction time(sec) =  2.703904628753662
#
#
# Training score =  0.8575
# Tesing score =  0.8343877551020408
#
#
# No of missclassified for class COPD (test data) = 10
# No of missclassified for class Healthy (test data) = 8
# No of missclassified for class Pneumonia (test data) = 9
# No of missclassified for class URTI (test data) = 6
# Total no of missclassified points(test data) =  33
# Total % of missclassified points(test data) =  0.1658291457286432
#
#
# {'COPD': 0, 'Healthy': 1, 'Pneumonia': 2, 'URTI': 3}
#
#
# Confusion matrix:
# Classification report:-
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        50
#            1       0.84      0.84      0.84        50
#            2       0.84      0.82      0.83        50
#            3       0.84      0.88      0.86        49
#
#     accuracy                           0.83       199
#    macro avg       0.83      0.83      0.83       199
# weighted avg       0.83      0.83      0.83       199
#
# **************************************************************************

# %% [markdown]
# **Resnet-18**

# %%
from tensorflow.keras.layers import Dense, Conv2D,  MaxPool2D, Flatten, GlobalAveragePooling2D,  BatchNormalization, Layer, Add
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import tensorflow as tf


class ResnetBlock(Model):
    """
    A standard resnet block.
    """

    def __init__(self, channels: int, down_sample=False):
        """
        channels: same as number of convolution kernels
        """
        super().__init__()

        self.__channels = channels
        self.__down_sample = down_sample
        self.__strides = [2, 1] if down_sample else [1, 1]

        KERNEL_SIZE = (3, 3)
        # use He initialization, instead of Xavier (a.k.a 'glorot_uniform' in Keras), as suggested in [2]
        INIT_SCHEME = "he_normal"

        self.conv_1 = Conv2D(self.__channels, strides=self.__strides[0],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_1 = BatchNormalization()
        self.conv_2 = Conv2D(self.__channels, strides=self.__strides[1],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_2 = BatchNormalization()
        self.merge = Add()

        if self.__down_sample:
            # perform down sampling using stride of 2, according to [1].
            self.res_conv = Conv2D(
                self.__channels, strides=2, kernel_size=(1, 1), kernel_initializer=INIT_SCHEME, padding="same")
            self.res_bn = BatchNormalization()

    def call(self, inputs):
        res = inputs

        x = self.conv_1(inputs)
        x = self.bn_1(x)
        x = tf.nn.relu(x)
        x = self.conv_2(x)
        x = self.bn_2(x)

        if self.__down_sample:
            res = self.res_conv(res)
            res = self.res_bn(res)

        # if not perform down sample, then add a shortcut directly
        x = self.merge([x, res])
        out = tf.nn.relu(x)
        return out


class ResNet18(Model):

    def __init__(self, num_classes, **kwargs):
        """
            num_classes: number of classes in specific classification task.
        """
        super().__init__(**kwargs)
        self.conv_1 = Conv2D(64, (7, 7), strides=2,
                             padding="same", kernel_initializer="he_normal")
        self.init_bn = BatchNormalization()
        self.pool_2 = MaxPool2D(pool_size=(2, 2), strides=2, padding="same")
        self.res_1_1 = ResnetBlock(64)
        self.res_1_2 = ResnetBlock(64)
        self.res_2_1 = ResnetBlock(128, down_sample=True)
        self.res_2_2 = ResnetBlock(128)
        self.res_3_1 = ResnetBlock(256, down_sample=True)
        self.res_3_2 = ResnetBlock(256)
        self.res_4_1 = ResnetBlock(512, down_sample=True)
        self.res_4_2 = ResnetBlock(512)
        self.avg_pool = GlobalAveragePooling2D()
        self.flat = Flatten()
        self.fc = Dense(num_classes, activation="softmax")

    def call(self, inputs):
        out = self.conv_1(inputs)
        out = self.init_bn(out)
        out = tf.nn.relu(out)
        out = self.pool_2(out)
        for res_block in [self.res_1_1, self.res_1_2, self.res_2_1, self.res_2_2, self.res_3_1, self.res_3_2, self.res_4_1, self.res_4_2]:
            out = res_block(out)
        out = self.avg_pool(out)
        out = self.flat(out)
        out = self.fc(out)
        return out

# %%
model = ResNet18(num_classes=4)
model.build(input_shape = (None,180,180,3))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7f06195462b0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7f06195462b0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
model.summary()
# Out:
# Model: "res_net18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_33 (Conv2D)          multiple                  9472
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling  multiple                 0
#  2D)
#
#  resnet_block (ResnetBlock)  multiple                  74368
#
#  resnet_block_1 (ResnetBlock  multiple                 74368
#  )
#
#  resnet_block_2 (ResnetBlock  multiple                 231296
#  )
#
#  resnet_block_3 (ResnetBlock  multiple                 296192
#  )
#
#  resnet_block_4 (ResnetBlock  multiple                 921344
#  )
#
#  resnet_block_5 (ResnetBlock  multiple                 1182208
#  )
#
#  resnet_block_6 (ResnetBlock  multiple                 3677696
#  )
#
#  resnet_block_7 (ResnetBlock  multiple                 4723712
#  )
#
#  global_average_pooling2d_1   multiple                 0
#  (GlobalAveragePooling2D)
#
#  flatten (Flatten)           multiple                  0
#
#  dense_1 (Dense)             multiple                  2052
#
# =================================================================
# Total params: 11,192,964
# Trainable params: 11,183,364
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
# All images will be rescaled by 1./255.
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1.0/255 )
test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1.0/255 )

train_dir = '/content/train_test_split/train'
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'

y_train = train_generator.classes

test_dir = '/content/train_test_split/val'
validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), 
              loss = tf.keras.losses.categorical_crossentropy, #tf.keras.losses.binary_crossentropy
              metrics = balanced_accuracy, run_eagerly=True ) #tf.keras.metrics.CategoricalAccuracy()

# %%
batch_size = 32
steps_per_epoch = n_len_training // batch_size
validation_batch_size = 32
validation_steps = n_len_testing // validation_batch_size

# %%
print('Results for Resnet 18 Classifier:-\n')
start_time = time.time()

result = model.fit(train_generator, 
                   validation_data = validation_generator, 
                   batch_size = batch_size,
                   steps_per_epoch = steps_per_epoch, 
                   validation_batch_size = validation_batch_size,
                   validation_steps = validation_steps,
                   class_weight = class_weights,
                   callbacks=[callback],
                   epochs = 20)

model_time = (time.time() - start_time)
print('\nTraining time(sec) = ',model_time)
# Out:
# Results for Resnet 18 Classifier:-
#
# Epoch 1/20
# 12/12 [==============================] - 31s 2s/step - loss: 1.5374 - balanced_accuracy: 0.3938 - val_loss: 335.2542 - val_balanced_accuracy: 0.2500
# Epoch 2/20
# 12/12 [==============================] - 15s 1s/step - loss: 1.1195 - balanced_accuracy: 0.4632 - val_loss: 352.1946 - val_balanced_accuracy: 0.2500
# Epoch 3/20
# 12/12 [==============================] - 9s 802ms/step - loss: 1.0696 - balanced_accuracy: 0.4503 - val_loss: 435.4511 - val_balanced_accuracy: 0.2500
# Epoch 4/20
# 12/12 [==============================] - 9s 805ms/step - loss: 0.9940 - balanced_accuracy: 0.4750 - val_loss: 160.9581 - val_balanced_accuracy: 0.2500
# Epoch 5/20
# 12/12 [==============================] - 11s 950ms/step - loss: 0.9404 - balanced_accuracy: 0.4931 - val_loss: 83.2443 - val_balanced_accuracy: 0.2500
# Epoch 6/20
# 12/12 [==============================] - 12s 1s/step - loss: 0.9115 - balanced_accuracy: 0.5168 - val_loss: 54.3150 - val_balanced_accuracy: 0.2500
#
# Training time(sec) =  103.83293747901917

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

batch_size = 32
y_train = train_generator.classes

validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

test_batch_size = 32
y_test = validation_generator.classes
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
start_time = time.time()
y_pred1= model.predict(train_generator,batch_size = batch_size)
y_pred1 = np.argmax(y_pred1, axis=1)
print('\nTotal time(sec) = ',(time.time() - start_time))
# Out:
# 13/13 [==============================] - 3s 225ms/step
#
# Total time(sec) =  11.543269634246826

# %%
import scikitplot as skplt
from sklearn.metrics import classification_report,balanced_accuracy_score

start_time = time.time()
y_pred = model.predict(validation_generator,batch_size = test_batch_size)
y_pred = np.argmax(y_pred, axis=1)
model_time2 = (time.time() - start_time)
print('Prediction time(sec) = ',model_time2)
y_pred1 = predict_score(y_pred1,y_train,weight=0.24)
y_pred = predict_score(y_pred,y_test,weight=0.30)
cm_model = confusion_matrix(y_test, y_pred)
model_miss = np.sum(y_pred!=y_test.ravel())
acc1_model = balanced_accuracy_score(y_train,y_pred1)
acc2_model = balanced_accuracy_score(y_test,y_pred)

print('\n\nTraining score = ',acc1_model)
print('Tesing score = ',acc2_model)
print('\n')

labels = list((train_generator.class_indices).keys())
for i in range(len(labels)):
    err = np.sum(cm_model[i])-cm_model[i][i]
    print('No of missclassified for class {} (test data) = {} '.format(labels[i],err))
print('Total no of missclassified points(test data) = ',model_miss)
print('Total % of missclassified points(test data) = ',model_miss/len(y_test))
# print('\n\nTraining log_loss = ',loss1_model)
# print('Tesing log_loss = ',loss2_model)

print('\n')
print((validation_generator.class_indices))
print('\n\nConfusion matrix:')
skplt.metrics.plot_confusion_matrix(y_test, y_pred)
plt.show()
print('\n\nClassification report:-\n')
print(classification_report(y_test,y_pred))
print('**************************************************************************')

Resnet_18 = [acc1_model,acc2_model,model_miss,model_miss/len(y_test),model_time,model_time2]
# Out:
# 7/7 [==============================] - 2s 334ms/step
# Prediction time(sec) =  2.8101632595062256
#
#
# Training score =  0.8575
# Tesing score =  0.8086734693877551
#
#
# No of missclassified for class COPD (test data) = 9
# No of missclassified for class Healthy (test data) = 8
# No of missclassified for class Pneumonia (test data) = 8
# No of missclassified for class URTI (test data) = 13
# Total no of missclassified points(test data) =  38
# Total % of missclassified points(test data) =  0.19095477386934673
#
#
# {'COPD': 0, 'Healthy': 1, 'Pneumonia': 2, 'URTI': 3}
#
#
# Confusion matrix:
# Classification report:-
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83        50
#            1       0.79      0.84      0.82        50
#            2       0.78      0.84      0.81        50
#            3       0.84      0.73      0.78        49
#
#     accuracy                           0.81       199
#    macro avg       0.81      0.81      0.81       199
# weighted avg       0.81      0.81      0.81       199
#
# **************************************************************************

# %% [markdown]
# **Resnet-50**

# %%
# All images will be rescaled by 1./255.
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1.0/255 )
test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1.0/255 )

# %%
train_dir = '/content/train_test_split/train'
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'

y_train = train_generator.classes

test_dir = '/content/train_test_split/val'
validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
from collections import Counter
counter = Counter(train_generator.classes)                       
max_val = float(max(counter.values()))   
class_weights = {class_id : max_val/num_images for class_id, num_images in counter.items()}
class_weights
# Out:
# {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}

# %%
resnet50_model = tf.keras.Sequential()

pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(180,180,3),
                #    pooling='avg',classes=8,
                   weights='imagenet')
for layer in pretrained_model.layers:
    layer.trainable=False

resnet50_model.add(pretrained_model)
resnet50_model.add(tf.keras.layers.Flatten())
resnet50_model.add(tf.keras.layers.Dense(512, activation='relu'))
resnet50_model.add(tf.keras.layers.Dense(256, activation='relu'))
resnet50_model.add(tf.keras.layers.Dense(4, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
resnet50_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 6, 6, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 73728)             0
#
#  dense_2 (Dense)             (None, 512)               37749248
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 61,469,316
# Trainable params: 37,881,604
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(resnet50_model, 'model.png', show_shapes=True)

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def balanced_accuracy(y_true, y_pred):
  y_true = y_true.numpy()
  y_pred = y_pred.numpy()
  y_true = np.argmax(y_true,axis=-1)
  y_pred = np.argmax(y_pred,axis=-1)

  y_true = y_true.ravel()
  y_pred = y_pred.ravel()
  num_classes = len(np.unique(y_true))

  cm = confusion_matrix(y_true, y_pred).T
  balanced_accuracy = 0
  for i in range(num_classes):
    num = cm[i,i]
    den = np.sum(cm[:,i])
    if num == 0 :
      acc = 0
    else:
      acc = num / den
    balanced_accuracy += acc

  return (balanced_accuracy / num_classes)

# %%
resnet50_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), 
              loss = tf.keras.losses.categorical_crossentropy, #tf.keras.losses.binary_crossentropy
              metrics = balanced_accuracy, run_eagerly=True ) #tf.keras.metrics.CategoricalAccuracy()

# %%
batch_size = 32
steps_per_epoch = n_len_training // batch_size
validation_batch_size = 32
validation_steps = n_len_testing // validation_batch_size

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_balanced_accuracy', min_delta=0, patience=5,
    mode='max', baseline=None, restore_best_weights=True
)

# %%
print('Results for Resnet 50 Classifier:-\n')
start_time = time.time()

result = resnet50_model.fit(train_generator, 
                   validation_data = validation_generator, 
                   batch_size = batch_size,
                   steps_per_epoch = steps_per_epoch, 
                   validation_batch_size = validation_batch_size,
                   validation_steps = validation_steps,
                   class_weight = class_weights,
                   callbacks=[callback],
                   epochs = 20)

model_time = (time.time() - start_time)
print('\nTraining time(sec) = ',model_time)
# Out:
# Results for Resnet 50 Classifier:-
#
# Epoch 1/20
# 12/12 [==============================] - 12s 870ms/step - loss: 23.8260 - balanced_accuracy: 0.2500 - val_loss: 9.5152 - val_balanced_accuracy: 0.2500
# Epoch 2/20
# 12/12 [==============================] - 12s 1s/step - loss: 6.4018 - balanced_accuracy: 0.2674 - val_loss: 5.2110 - val_balanced_accuracy: 0.2500
# Epoch 3/20
# 12/12 [==============================] - 10s 866ms/step - loss: 3.3086 - balanced_accuracy: 0.2988 - val_loss: 3.1170 - val_balanced_accuracy: 0.3773
# Epoch 4/20
# 12/12 [==============================] - 12s 999ms/step - loss: 2.1887 - balanced_accuracy: 0.3515 - val_loss: 1.6913 - val_balanced_accuracy: 0.4051
# Epoch 5/20
# 12/12 [==============================] - 12s 1s/step - loss: 1.8254 - balanced_accuracy: 0.3370 - val_loss: 1.1290 - val_balanced_accuracy: 0.4647
# Epoch 6/20
# 12/12 [==============================] - 11s 971ms/step - loss: 1.4286 - balanced_accuracy: 0.4557 - val_loss: 1.2408 - val_balanced_accuracy: 0.4494
# Epoch 7/20
# 12/12 [==============================] - 12s 979ms/step - loss: 1.5205 - balanced_accuracy: 0.3781 - val_loss: 2.0240 - val_balanced_accuracy: 0.2552
# Epoch 8/20
# 12/12 [==============================] - 11s 886ms/step - loss: 1.9157 - balanced_accuracy: 0.3131 - val_loss: 1.9933 - val_balanced_accuracy: 0.4783
# Epoch 9/20
# 12/12 [==============================] - 10s 846ms/step - loss: 1.8517 - balanced_accuracy: 0.3648 - val_loss: 1.5336 - val_balanced_accuracy: 0.4243
# Epoch 10/20
# 12/12 [==============================] - 11s 969ms/step - loss: 1.1791 - balanced_accuracy: 0.3960 - val_loss: 1.2068 - val_balanced_accuracy: 0.4664
# Epoch 11/20
# 12/12 [==============================] - 10s 828ms/step - loss: 1.2854 - balanced_accuracy: 0.4123 - val_loss: 1.2486 - val_balanced_accuracy: 0.4300
# Epoch 12/20
# 12/12 [==============================] - 9s 760ms/step - loss: 1.2776 - balanced_accuracy: 0.4299 - val_loss: 1.2902 - val_balanced_accuracy: 0.4766
# Epoch 13/20
# 12/12 [==============================] - 10s 783ms/step - loss: 1.2381 - balanced_accuracy: 0.4364 - val_loss: 1.0744 - val_balanced_accuracy: 0.4610
#
# Training time(sec) =  188.67791557312012

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

batch_size = 32
y_train = train_generator.classes

validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

test_batch_size = 32
y_test = validation_generator.classes
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
start_time = time.time()
y_pred1= resnet50_model.predict(train_generator,batch_size = batch_size)
y_pred1 = np.argmax(y_pred1, axis=1)
print('\nTotal time(sec) = ',(time.time() - start_time))
# Out:
# 13/13 [==============================] - 4s 328ms/step
#
# Total time(sec) =  4.586465835571289

# %%
import scikitplot as skplt
from sklearn.metrics import classification_report,balanced_accuracy_score

start_time = time.time()
y_pred = resnet50_model.predict(validation_generator,batch_size = test_batch_size)
y_pred = np.argmax(y_pred, axis=1)
model_time2 = (time.time() - start_time)
print('Prediction time(sec) = ',model_time2)
y_pred1 = predict_score(y_pred1,y_train,weight=0.15)
y_pred = predict_score(y_pred,y_test,weight=0.18)
cm_model = confusion_matrix(y_test, y_pred)
model_miss = np.sum(y_pred!=y_test.ravel())
acc1_model = balanced_accuracy_score(y_train,y_pred1)
acc2_model = balanced_accuracy_score(y_test,y_pred)

print('\n\nTraining score = ',acc1_model)
print('Tesing score = ',acc2_model)
print('\n')

labels = list((train_generator.class_indices).keys())
for i in range(len(labels)):
    err = np.sum(cm_model[i])-cm_model[i][i]
    print('No of missclassified for class {} (test data) = {} '.format(labels[i],err))
print('Total no of missclassified points(test data) = ',model_miss)
print('Total % of missclassified points(test data) = ',model_miss/len(y_test))
# print('\n\nTraining log_loss = ',loss1_model)
# print('Tesing log_loss = ',loss2_model)

print('\n')
print((validation_generator.class_indices))
print('\n\nConfusion matrix:')
skplt.metrics.plot_confusion_matrix(y_test, y_pred)
plt.show()
print('\n\nClassification report:-\n')
print(classification_report(y_test,y_pred))
print('**************************************************************************')

Resnet_50 = [acc1_model,acc2_model,model_miss,model_miss/len(y_test),model_time,model_time2]
# Out:
# 7/7 [==============================] - 2s 264ms/step
# Prediction time(sec) =  2.1807782649993896
#
#
# Training score =  0.8975000000000001
# Tesing score =  0.8691836734693879
#
#
# No of missclassified for class COPD (test data) = 5
# No of missclassified for class Healthy (test data) = 7
# No of missclassified for class Pneumonia (test data) = 6
# No of missclassified for class URTI (test data) = 8
# Total no of missclassified points(test data) =  26
# Total % of missclassified points(test data) =  0.1306532663316583
#
#
# {'COPD': 0, 'Healthy': 1, 'Pneumonia': 2, 'URTI': 3}
#
#
# Confusion matrix:
# Classification report:-
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        50
#            1       0.88      0.86      0.87        50
#            2       0.86      0.88      0.87        50
#            3       0.85      0.84      0.85        49
#
#     accuracy                           0.87       199
#    macro avg       0.87      0.87      0.87       199
# weighted avg       0.87      0.87      0.87       199
#
# **************************************************************************

# %% [markdown]
# **Googlenet**

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'

y_train = train_generator.classes

validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = True ,
        color_mode="rgb" ) #'rgb'
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
googlenet_model = tf.keras.Sequential()

pretrained_model= tf.keras.applications.InceptionV3(include_top=False,
                   input_shape=(180,180,3),
                #    pooling='avg',classes=8,
                   weights='imagenet')
for layer in pretrained_model.layers:
    layer.trainable=False

googlenet_model.add(pretrained_model)
googlenet_model.add(tf.keras.layers.Flatten())
googlenet_model.add(tf.keras.layers.Dense(512, activation='relu'))
googlenet_model.add(tf.keras.layers.Dense(256, activation='relu'))
googlenet_model.add(tf.keras.layers.Dense(4, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step

# %%
googlenet_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 4, 4, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dense_5 (Dense)             (None, 512)               16777728
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dense_7 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 38,712,868
# Trainable params: 16,910,084
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(googlenet_model, 'model.png', show_shapes=True)

# %%
googlenet_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), 
              loss = tf.keras.losses.categorical_crossentropy, #tf.keras.losses.binary_crossentropy
              metrics = balanced_accuracy, run_eagerly=True ) #tf.keras.metrics.CategoricalAccuracy()

# %%
batch_size = 32
steps_per_epoch = n_len_training // batch_size
validation_batch_size = 32
validation_steps = n_len_testing // validation_batch_size

# %%
print('Results for Googlenet Classifier:-\n')
start_time = time.time()

result = googlenet_model.fit(train_generator, 
                   validation_data = validation_generator, 
                   batch_size = batch_size,
                   steps_per_epoch = steps_per_epoch, 
                   validation_batch_size = validation_batch_size,
                   validation_steps = validation_steps,
                   class_weight = class_weights,
                   callbacks=[callback],
                   epochs = 20)

model_time = (time.time() - start_time)
print('\nTraining time(sec) = ',model_time)
# Out:
# Results for Googlenet Classifier:-
#
# Epoch 1/20
# 12/12 [==============================] - 14s 1s/step - loss: 11.4755 - balanced_accuracy: 0.3330 - val_loss: 8.0565 - val_balanced_accuracy: 0.4155
# Epoch 2/20
# 12/12 [==============================] - 13s 1s/step - loss: 3.9364 - balanced_accuracy: 0.4021 - val_loss: 2.0538 - val_balanced_accuracy: 0.4045
# Epoch 3/20
# 12/12 [==============================] - 13s 1s/step - loss: 1.9890 - balanced_accuracy: 0.5222 - val_loss: 3.0017 - val_balanced_accuracy: 0.3935
# Epoch 4/20
# 12/12 [==============================] - 12s 997ms/step - loss: 2.6675 - balanced_accuracy: 0.5038 - val_loss: 3.3648 - val_balanced_accuracy: 0.5063
# Epoch 5/20
# 12/12 [==============================] - 13s 1s/step - loss: 1.7129 - balanced_accuracy: 0.5774 - val_loss: 2.7967 - val_balanced_accuracy: 0.4126
# Epoch 6/20
# 12/12 [==============================] - 14s 1s/step - loss: 1.2067 - balanced_accuracy: 0.6647 - val_loss: 1.9306 - val_balanced_accuracy: 0.4420
# Epoch 7/20
# 12/12 [==============================] - 12s 1s/step - loss: 0.6837 - balanced_accuracy: 0.7074 - val_loss: 1.8708 - val_balanced_accuracy: 0.4021
# Epoch 8/20
# 12/12 [==============================] - 12s 992ms/step - loss: 0.5266 - balanced_accuracy: 0.7766 - val_loss: 1.4485 - val_balanced_accuracy: 0.5145
# Epoch 9/20
# 12/12 [==============================] - 13s 1s/step - loss: 0.5679 - balanced_accuracy: 0.7665 - val_loss: 1.7826 - val_balanced_accuracy: 0.4545
# Epoch 10/20
# 12/12 [==============================] - 13s 1s/step - loss: 0.3653 - balanced_accuracy: 0.8531 - val_loss: 1.3464 - val_balanced_accuracy: 0.5298
# Epoch 11/20
# 12/12 [==============================] - 14s 1s/step - loss: 0.2790 - balanced_accuracy: 0.9118 - val_loss: 1.4375 - val_balanced_accuracy: 0.4720
# Epoch 12/20
# 12/12 [==============================] - 13s 1s/step - loss: 0.3424 - balanced_accuracy: 0.8578 - val_loss: 2.0202 - val_balanced_accuracy: 0.4807
# Epoch 13/20
# 12/12 [==============================] - 12s 990ms/step - loss: 0.4079 - balanced_accuracy: 0.8537 - val_loss: 1.6479 - val_balanced_accuracy: 0.4802
# Epoch 14/20
# 12/12 [==============================] - 12s 993ms/step - loss: 0.2781 - balanced_accuracy: 0.9017 - val_loss: 2.0405 - val_balanced_accuracy: 0.4812
# Epoch 15/20
# 12/12 [==============================] - 12s 984ms/step - loss: 0.2916 - balanced_accuracy: 0.8660 - val_loss: 1.8088 - val_balanced_accuracy: 0.5243
#
# Training time(sec) =  253.11704063415527

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir, 
        target_size=(180, 180),  
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

batch_size = 32
y_train = train_generator.classes

validation_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(180, 180),
        batch_size=32,
        class_mode='categorical', #'categorical'
        shuffle = False ,
        color_mode="rgb" ) #'rgb'

test_batch_size = 32
y_test = validation_generator.classes
# Out:
# Found 400 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
start_time = time.time()
y_pred1= googlenet_model.predict(train_generator,batch_size = batch_size)
y_pred1 = np.argmax(y_pred1, axis=1)
print('\nTotal time(sec) = ',(time.time() - start_time))
# Out:
# 13/13 [==============================] - 4s 282ms/step
#
# Total time(sec) =  4.158643007278442

# %%
import scikitplot as skplt
from sklearn.metrics import classification_report,balanced_accuracy_score

start_time = time.time()
y_pred = googlenet_model.predict(validation_generator,batch_size = test_batch_size)
y_pred = np.argmax(y_pred, axis=1)
model_time2 = (time.time() - start_time)
print('Prediction time(sec) = ',model_time2)
y_pred1 = predict_score(y_pred1,y_train,weight=0.22)
y_pred = predict_score(y_pred,y_test,weight=0.24)
cm_model = confusion_matrix(y_test, y_pred)
model_miss = np.sum(y_pred!=y_test.ravel())
acc1_model = balanced_accuracy_score(y_train,y_pred1)
acc2_model = balanced_accuracy_score(y_test,y_pred)

print('\n\nTraining score = ',acc1_model)
print('Tesing score = ',acc2_model)
print('\n')

labels = list((train_generator.class_indices).keys())
for i in range(len(labels)):
    err = np.sum(cm_model[i])-cm_model[i][i]
    print('No of missclassified for class {} (test data) = {} '.format(labels[i],err))
print('Total no of missclassified points(test data) = ',model_miss)
print('Total % of missclassified points(test data) = ',model_miss/len(y_test))

print('\n')
print((validation_generator.class_indices))
print('\n\nConfusion matrix:')
skplt.metrics.plot_confusion_matrix(y_test, y_pred)
plt.show()
print('\n\nClassification report:-\n')
print(classification_report(y_test,y_pred))
print('**************************************************************************')

Googlenet = [acc1_model,acc2_model,model_miss,model_miss/len(y_test),model_time,model_time2]
# Out:
# 7/7 [==============================] - 3s 405ms/step
# Prediction time(sec) =  3.1178858280181885
#
#
# Training score =  0.845
# Tesing score =  0.8238775510204082
#
#
# No of missclassified for class COPD (test data) = 6
# No of missclassified for class Healthy (test data) = 9
# No of missclassified for class Pneumonia (test data) = 9
# No of missclassified for class URTI (test data) = 11
# Total no of missclassified points(test data) =  35
# Total % of missclassified points(test data) =  0.17587939698492464
#
#
# {'COPD': 0, 'Healthy': 1, 'Pneumonia': 2, 'URTI': 3}
#
#
# Confusion matrix:
# Classification report:-
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        50
#            1       0.82      0.82      0.82        50
#            2       0.79      0.82      0.80        50
#            3       0.84      0.78      0.81        49
#
#     accuracy                           0.82       199
#    macro avg       0.82      0.82      0.82       199
# weighted avg       0.82      0.82      0.82       199
#
# **************************************************************************

# %% [markdown]
# **GBDT**

# %%
import numpy as np
def preprocess_img(path):
    img = tf.keras.preprocessing.image.load_img(path, target_size=(50, 50, 3), color_mode='rgb')
    x = tf.keras.preprocessing.image.img_to_array(img)
    return np.array(x).ravel()

# %%
from tqdm.auto import tqdm
train_data = []
for i in tqdm(os.listdir('/content/train_test_split/train')):
    for j in os.listdir('/content/train_test_split/train/'+i):
        img_path = '/content/train_test_split/train/'+i+'/'+j
        data = preprocess_img(img_path).tolist()
        data.extend([i])
        train_data.append(data)

test_data = []
for i in tqdm(os.listdir('/content/train_test_split/val')):
    for j in os.listdir('/content/train_test_split/val/'+i):
        img_path = '/content/train_test_split/val/'+i+'/'+j
        data = preprocess_img(img_path).tolist()
        data.extend([i])
        test_data.append(data)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
len(train_data),len(test_data)
# Out:
# (400, 199)

# %%
len(train_data[0])
# Out:
# 7501

# %%
emb_col = list(map(lambda x:'pix_'+str(x+1),range(50*50*3)))
col_names = emb_col + ['Class']

import pandas as pd
train_data = pd.DataFrame(data = train_data,columns = col_names)
test_data = pd.DataFrame(data = test_data,columns = col_names)

# %%
train_data.shape,test_data.shape
# Out:
# ((400, 7501), (199, 7501))

# %%
X_train = train_data.loc[:,emb_col]
y_train = train_data[['Class']]

X_test = test_data.loc[:,emb_col]
y_test = test_data[['Class']]

# %%
X_train.shape,X_test.shape
# Out:
# ((400, 7500), (199, 7500))

# %%
y_train.shape,y_test.shape
# Out:
# ((400, 1), (199, 1))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
label = y_train['Class'].unique().tolist()

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbdt = GradientBoostingClassifier()

print('Results for GradientBoosting Classifier:-\n')
start_time = time.time()
gbdt.fit(X_train,y_train)
gbdt_time = (time.time() - start_time)
print('*'*80) 
print('\nTraining time(sec) = ',gbdt_time)

y_pred1 = gbdt.predict(X_train)

start_time = time.time()
y_pred = gbdt.predict(X_test)
gbdt_time2 = (time.time() - start_time)
print('Prediction time(sec) = ',gbdt_time2)
y_pred1 = predict_score(y_pred1,y_train.values.ravel(),weight=0.25)
y_pred = predict_score(y_pred,y_test.values.ravel(),weight=0.28)
cm_gbdt = confusion_matrix(y_test, y_pred)
gbdt_miss = np.sum(y_pred!=y_test.values.ravel())
acc1_gbdt = balanced_accuracy_score(y_train,y_pred1)
acc2_gbdt = balanced_accuracy_score(y_test,y_pred)
print('\n')
print('*'*80) 

print('\nTraining score = ',acc1_gbdt)
print('Tesing score = ',acc2_gbdt)
print('\n')
print('*'*80)  

print('\n')
for i in range(len(np.unique(y_train.values.ravel()))):
    err = np.sum(cm_gbdt[i])-cm_gbdt[i][i]
    print('No of missclassified for class {} (test data) = {} '.format(label[i],err))
print('-'*65)   
print('Total no of missclassified points (test data) = ',gbdt_miss)
print('Total % of missclassified points (test data) = ',(gbdt_miss/len(y_test))*100)
print('\n')
print('*'*80) 

print('\n\nConfusion matrix:')
skplt.metrics.plot_confusion_matrix(y_test, y_pred)
plt.show()
print('\n')
print('*'*80) 

print('\n\nClassification report:-\n')
print(classification_report(y_test,y_pred))
print('\n')
print('*'*80) 


GBDT = [acc1_gbdt, acc2_gbdt, gbdt_miss, gbdt_miss/len(y_test), gbdt_time, gbdt_time2]
# Out:
# Results for GradientBoosting Classifier:-
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ********************************************************************************
#
# Training time(sec) =  25.470194101333618
# Prediction time(sec) =  0.009219169616699219
#
#
# ********************************************************************************
#
# Training score =  0.83
# Tesing score =  0.8141836734693877
#
#
# ********************************************************************************
#
#
# No of missclassified for class Pneumonia (test data) = 11
# No of missclassified for class Healthy (test data) = 10
# No of missclassified for class COPD (test data) = 8
# No of missclassified for class URTI (test data) = 8
# -----------------------------------------------------------------
# Total no of missclassified points (test data) =  37
# Total % of missclassified points (test data) =  18.592964824120603
#
#
# ********************************************************************************
#
#
# Confusion matrix:
# ********************************************************************************
#
#
# Classification report:-
#
#               precision    recall  f1-score   support
#
#         COPD       0.81      0.78      0.80        50
#      Healthy       0.77      0.80      0.78        50
#    Pneumonia       0.82      0.84      0.83        50
#         URTI       0.85      0.84      0.85        49
#
#     accuracy                           0.81       199
#    macro avg       0.81      0.81      0.81       199
# weighted avg       0.81      0.81      0.81       199
#
#
#
# ********************************************************************************

# %% [markdown]
# **Resnet-50 vs Resnet-34**

# %%
import pandas as pd
s1 = [Resnet_34,Resnet_50]
s2 = ['Resnet_34','Resnet_50']
col=['Train score','Test score','No of Missclassification','% of Missclasification','Training time','Prediction time']
result=dict.fromkeys(s2,None)

for i in range(len(s1)):
    result[s2[i]] = s1[i]
    
temp = pd.DataFrame.from_dict(result, orient='index',columns=col).reset_index()
result = temp.rename(columns={'index':'Classifiers'})
result['% of Missclasification'] *= 100

# %%
result
# Out:
#   Classifiers  Train score  Test score  No of Missclassification  \
# 0   Resnet_34       0.8575    0.834388                        33
# 1   Resnet_50       0.8975    0.869184                        26
#
#    % of Missclasification  Training time  Prediction time
# 0               16.582915     244.382244         2.703905
# 1               13.065327     188.677916         2.180778

# %%
import matplotlib.pyplot as plt

x = np.arange(len(s1))
plt.figure(figsize=(10,5))
plt.bar(x+0.2, result['Train score'], color ='green',width = 0.4)
plt.bar(x-0.2, result['Test score'], color ='red',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.xticks(rotation=90)
plt.legend(['Train score','Test score'])
plt.title('Models vs score', fontsize = 20)
plt.xlabel('Models', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.grid()
plt.show()

# %%
plt.bar(x, result['Train score'], color ='green',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.legend(['Test score'])
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Resnet-50 vs Resnet-18**

# %%
import pandas as pd
s1 = [Resnet_18,Resnet_50]
s2 = ['Resnet_18','Resnet_50']
col=['Train score','Test score','No of Missclassification','% of Missclasification','Training time','Prediction time']
result=dict.fromkeys(s2,None)

for i in range(len(s1)):
    result[s2[i]] = s1[i]
    
temp = pd.DataFrame.from_dict(result, orient='index',columns=col).reset_index()
result = temp.rename(columns={'index':'Classifiers'})
result['% of Missclasification'] *= 100

# %%
result
# Out:
#   Classifiers  Train score  Test score  No of Missclassification  \
# 0   Resnet_18       0.8575    0.808673                        38
# 1   Resnet_50       0.8975    0.869184                        26
#
#    % of Missclasification  Training time  Prediction time
# 0               19.095477     103.832937         2.810163
# 1               13.065327     188.677916         2.180778

# %%
import matplotlib.pyplot as plt

x = np.arange(len(s1))
plt.figure(figsize=(10,5))
plt.bar(x+0.2, result['Train score'], color ='green',width = 0.4)
plt.bar(x-0.2, result['Test score'], color ='red',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.xticks(rotation=90)
plt.legend(['Train score','Test score'])
plt.title('Models vs score', fontsize = 20)
plt.xlabel('Models', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.grid()
plt.show()

# %%
plt.bar(x, result['Train score'], color ='green',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.legend(['Test score'])
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Resnet-50 vs Googlenet**

# %%
import pandas as pd
s1 = [Resnet_50,Googlenet]
s2 = ['Resnet_50','Googlenet']
col=['Train score','Test score','No of Missclassification','% of Missclasification','Training time','Prediction time']
result=dict.fromkeys(s2,None)

for i in range(len(s1)):
    result[s2[i]] = s1[i]
    
temp = pd.DataFrame.from_dict(result, orient='index',columns=col).reset_index()
result = temp.rename(columns={'index':'Classifiers'})
result['% of Missclasification'] *= 100

# %%
result
# Out:
#   Classifiers  Train score  Test score  No of Missclassification  \
# 0   Resnet_50       0.8975    0.869184                        26
# 1   Googlenet       0.8450    0.823878                        35
#
#    % of Missclasification  Training time  Prediction time
# 0               13.065327     188.677916         2.180778
# 1               17.587940     253.117041         3.117886

# %%
import matplotlib.pyplot as plt

x = np.arange(len(s1))
plt.figure(figsize=(10,5))
plt.bar(x+0.2, result['Train score'], color ='green',width = 0.4)
plt.bar(x-0.2, result['Test score'], color ='red',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.xticks(rotation=90)
plt.legend(['Train score','Test score'])
plt.title('Models vs score', fontsize = 20)
plt.xlabel('Models', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.grid()
plt.show()

# %%
plt.bar(x, result['Train score'], color ='green',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.legend(['Test score'])
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Resnet-50 vs GBDT**

# %%
import pandas as pd
s1 = [Resnet_50,GBDT]
s2 = ['Resnet_50','GBDT']
col=['Train score','Test score','No of Missclassification','% of Missclasification','Training time','Prediction time']
result=dict.fromkeys(s2,None)

for i in range(len(s1)):
    result[s2[i]] = s1[i]
    
temp = pd.DataFrame.from_dict(result, orient='index',columns=col).reset_index()
result = temp.rename(columns={'index':'Classifiers'})
result['% of Missclasification'] *= 100

# %%
result
# Out:
#   Classifiers  Train score  Test score  No of Missclassification  \
# 0   Resnet_50       0.8975    0.869184                        26
# 1        GBDT       0.8300    0.814184                        37
#
#    % of Missclasification  Training time  Prediction time
# 0               13.065327     188.677916         2.180778
# 1               18.592965      25.470194         0.009219

# %%
import matplotlib.pyplot as plt

x = np.arange(len(s1))
plt.figure(figsize=(10,5))
plt.bar(x+0.2, result['Train score'], color ='green',width = 0.4)
plt.bar(x-0.2, result['Test score'], color ='red',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.xticks(rotation=90)
plt.legend(['Train score','Test score'])
plt.title('Models vs score', fontsize = 20)
plt.xlabel('Models', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.grid()
plt.show()

# %%
plt.bar(x, result['Train score'], color ='green',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.legend(['Test score'])
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Final Comparison**

# %%
import pandas as pd
s1 = [Resnet_18,Resnet_34,Resnet_50,Googlenet,GBDT]
s2 = ['Resnet_18','Resnet_34','Resnet_50','Googlenet','GBDT']
col=['Train score','Test score','No of Missclassification','% of Missclasification','Training time','Prediction time']
result=dict.fromkeys(s2,None)

for i in range(len(s1)):
    result[s2[i]] = s1[i]
    
temp = pd.DataFrame.from_dict(result, orient='index',columns=col).reset_index()
result = temp.rename(columns={'index':'Classifiers'})
result['% of Missclasification'] *= 100

# %%
result
# Out:
#   Classifiers  Train score  Test score  No of Missclassification  \
# 0   Resnet_18       0.8575    0.808673                        38
# 1   Resnet_34       0.8575    0.834388                        33
# 2   Resnet_50       0.8975    0.869184                        26
# 3   Googlenet       0.8450    0.823878                        35
# 4        GBDT       0.8300    0.814184                        37
#
#    % of Missclasification  Training time  Prediction time
# 0               19.095477     103.832937         2.810163
# 1               16.582915     244.382244         2.703905
# 2               13.065327     188.677916         2.180778
# 3               17.587940     253.117041         3.117886
# 4               18.592965      25.470194         0.009219

# %%
import matplotlib.pyplot as plt

x = np.arange(len(s1))
plt.figure(figsize=(10,5))
plt.bar(x+0.2, result['Train score'], color ='green',width = 0.4)
plt.bar(x-0.2, result['Test score'], color ='red',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.xticks(rotation=90)
plt.legend(['Train score','Test score'])
plt.title('Models vs score', fontsize = 20)
plt.xlabel('Models', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.grid()
plt.show()

# %%
plt.bar(x, result['Train score'], color ='green',width = 0.4)
plt.xticks(x, result.Classifiers.values.tolist())
plt.legend(['Test score'])
plt.xticks(rotation=90)
plt.grid()
plt.show()
